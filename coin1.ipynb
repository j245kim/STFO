# %%
# pip install pyupbit

# %%
# pip install pyjwt

# %%
import pyupbit

# %%
import requests
import time
from datetime import datetime

# 1. API 요청을 보낼 URL 설정
url = "https://api.upbit.com/v1/ticker"
query = {"markets": "KRW-BTC"}  # 예: 비트코인

# 2. 데이터 요청
response = requests.get(url, params=query)
data = response.json()

# 3. API 응답 확인
if response.status_code == 200 and data:
    # 데이터의 타임스탬프 확인
    trade_timestamp = data[0]['trade_timestamp']  # Unix 타임스탬프
    trade_time = datetime.fromtimestamp(trade_timestamp / 1000)  # 밀리초를 초로 변환
    
    # 현재 시간과 비교
    now = datetime.now()
    time_diff = now - trade_time
    
    print(f"데이터 거래 시간: {trade_time}")
    print(f"현재 시간: {now}")
    print(f"데이터 지연 시간: {time_diff}")

    # 데이터가 최근 10초 내에 업데이트되었는지 확인
    if time_diff.total_seconds() < 10:
        print("데이터는 최신입니다!")
    else:
        print("데이터가 오래되었습니다.")
else:
    print(f"API 요청 실패: {response.status_code}")
# Out:
# 데이터 거래 시간: 2024-12-05 17:01:00.550000
# 현재 시간: 2024-12-05 17:01:02.701526
# 데이터 지연 시간: 0:00:02.151526
# 데이터는 최신입니다!

# %%
print(pyupbit.get_tickers())
# Out:
# ['KRW-BTC', 'KRW-ETH', 'BTC-ETH', 'BTC-XRP', 'BTC-ETC', 'BTC-CVC', 'BTC-DGB', 'BTC-SC', 'BTC-SNT', 'BTC-WAVES', 'BTC-NMR', 'BTC-XEM', 'BTC-QTUM', 'BTC-BAT', 'BTC-LSK', 'BTC-STEEM', 'BTC-DOGE', 'BTC-BNT', 'BTC-XLM', 'BTC-ARDR', 'BTC-ARK', 'BTC-STORJ', 'BTC-GRS', 'BTC-RLC', 'USDT-BTC', 'USDT-ETH', 'USDT-XRP', 'USDT-ETC', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-ETC', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-ADA', 'BTC-ADA', 'BTC-MANA', 'KRW-SBD', 'BTC-SBD', 'KRW-POWR', 'BTC-POWR', 'KRW-BTG', 'USDT-ADA', 'BTC-DNT', 'BTC-ZRX', 'BTC-TRX', 'BTC-TUSD', 'BTC-LRC', 'KRW-ICX', 'KRW-EOS', 'USDT-TUSD', 'KRW-TRX', 'BTC-POLYX', 'USDT-SC', 'USDT-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLYX', 'KRW-ZRX', 'KRW-LOOM', 'BTC-BCH', 'USDT-BCH', 'KRW-BCH', 'BTC-HIFI', 'BTC-LOOM', 'KRW-BAT', 'KRW-IOST', 'USDT-DGB', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'BTC-RVN', 'BTC-GO', 'BTC-BOUNTY', 'BTC-ENJ', 'KRW-HIFI', 'KRW-ONG', 
# ...

# %%
print(pyupbit.get_tickers(fiat="KRW"))
# Out:
# ['KRW-BTC', 'KRW-ETH', 'KRW-NEO', 'KRW-MTL', 'KRW-XRP', 'KRW-ETC', 'KRW-SNT', 'KRW-WAVES', 'KRW-XEM', 'KRW-QTUM', 'KRW-LSK', 'KRW-STEEM', 'KRW-XLM', 'KRW-ARDR', 'KRW-ARK', 'KRW-STORJ', 'KRW-GRS', 'KRW-ADA', 'KRW-SBD', 'KRW-POWR', 'KRW-BTG', 'KRW-ICX', 'KRW-EOS', 'KRW-TRX', 'KRW-SC', 'KRW-ONT', 'KRW-ZIL', 'KRW-POLYX', 'KRW-ZRX', 'KRW-LOOM', 'KRW-BCH', 'KRW-BAT', 'KRW-IOST', 'KRW-CVC', 'KRW-IQ', 'KRW-IOTA', 'KRW-HIFI', 'KRW-ONG', 'KRW-GAS', 'KRW-BOUNTY', 'KRW-ELF', 'KRW-KNC', 'KRW-BSV', 'KRW-THETA', 'KRW-QKC', 'KRW-BTT', 'KRW-MOC', 'KRW-TFUEL', 'KRW-MANA', 'KRW-ANKR', 'KRW-AERGO', 'KRW-ATOM', 'KRW-TT', 'KRW-GAME2', 'KRW-MBL', 'KRW-WAXP', 'KRW-HBAR', 'KRW-MED', 'KRW-MLK', 'KRW-STPT', 'KRW-ORBS', 'KRW-VET', 'KRW-CHZ', 'KRW-STMX', 'KRW-DKA', 'KRW-HIVE', 'KRW-KAVA', 'KRW-AHT', 'KRW-LINK', 'KRW-XTZ', 'KRW-BORA', 'KRW-JST', 'KRW-CRO', 'KRW-TON', 'KRW-SXP', 'KRW-HUNT', 'KRW-DOT', 'KRW-MVL', 'KRW-STRAX', 'KRW-AQT', 'KRW-GLM', 'KRW-META', 'KRW-FCT2', 'KRW-CBK', 'KRW-SAND', 'KRW-HPO', 'KRW-DOGE'
# ...

# %%
print(pyupbit.get_current_price("KRW-BTC"))
# Out:
# 143729000.0

# %%
print(pyupbit.get_current_price(["KRW-BTC", "KRW-XRP"]))
# Out:
# {'KRW-BTC': 143729000.0, 'KRW-XRP': 3328.0}

# %%
df = pyupbit.get_ohlcv("KRW-BTC")
print(df.tail())
# Out:
#                             open         high          low        close  \
# 2024-12-01 09:00:00  133722000.0  135199000.0  133297000.0  133802000.0
# 2024-12-02 09:00:00  133802000.0  135800000.0  132260000.0  133535000.0
# 2024-12-03 09:00:00  133523000.0  134680000.0   88266000.0  133700000.0
# 2024-12-04 09:00:00  133720000.0  139920000.0  133499000.0  138760000.0
# 2024-12-05 09:00:00  138765000.0  146100000.0  136980000.0  143799000.0
#
#                            volume         value
# 2024-12-01 09:00:00   2835.146498  3.809287e+11
# 2024-12-02 09:00:00   5356.774825  7.180606e+11
# 2024-12-03 09:00:00  18097.084256  2.304644e+12
# 2024-12-04 09:00:00   6969.870812  9.488602e+11
# 2024-12-05 09:00:00   7893.138973  1.126060e+12

# %%
df = pyupbit.get_ohlcv("KRW-BTC", count=5)

# %%
df
# Out:
#                             open         high          low        close  \
# 2024-12-01 09:00:00  133722000.0  135199000.0  133297000.0  133802000.0
# 2024-12-02 09:00:00  133802000.0  135800000.0  132260000.0  133535000.0
# 2024-12-03 09:00:00  133523000.0  134680000.0   88266000.0  133700000.0
# 2024-12-04 09:00:00  133720000.0  139920000.0  133499000.0  138760000.0
# 2024-12-05 09:00:00  138765000.0  146100000.0  136980000.0  143729000.0
#
#                            volume         value
# 2024-12-01 09:00:00   2835.146498  3.809287e+11
# 2024-12-02 09:00:00   5356.774825  7.180606e+11
# 2024-12-03 09:00:00  18097.084256  2.304644e+12
# 2024-12-04 09:00:00   6969.870812  9.488602e+11
# 2024-12-05 09:00:00   7893.244695  1.126075e+12

# %%
df = pyupbit.get_ohlcv("KRW-BTC", count=600, period=1)

# %%
df
# Out:
#                             open         high          low        close  \
# 2023-04-16 09:00:00   39800000.0   39981000.0   39600000.0   39607000.0
# 2023-04-17 09:00:00   39612000.0   39673000.0   38506000.0   38700000.0
# 2023-04-18 09:00:00   38700000.0   39847000.0   38251000.0   39630000.0
# 2023-04-19 09:00:00   39637000.0   39719000.0   38181000.0   38300000.0
# 2023-04-20 09:00:00   38300000.0   38572000.0   37400000.0   37672000.0
# ...                          ...          ...          ...          ...
# 2024-12-01 09:00:00  133722000.0  135199000.0  133297000.0  133802000.0
# 2024-12-02 09:00:00  133802000.0  135800000.0  132260000.0  133535000.0
# 2024-12-03 09:00:00  133523000.0  134680000.0   88266000.0  133700000.0
# 2024-12-04 09:00:00  133720000.0  139920000.0  133499000.0  138760000.0
# 2024-12-05 09:00:00  138765000.0  146100000.0  136980000.0  143729000.0
#
#                            volume         value
# 2023-04-16 09:00:00   2393.495282  9.512904e+10
# ...

# %%
print(pyupbit.get_ohlcv("KRW-BTC", interval="day"))              # 일봉 데이터 (5일)
print(pyupbit.get_ohlcv("KRW-BTC", interval="minute1"))         # 분봉 데이터
print(pyupbit.get_ohlcv("KRW-BTC", interval="week"))            # 주봉 데이터
# Out:
#                             open         high          low        close  \
# 2024-05-20 09:00:00   92185000.0   97264000.0   91931000.0   97260000.0
# 2024-05-21 09:00:00   97260000.0   98150000.0   95571000.0   96700000.0
# 2024-05-22 09:00:00   96717000.0   96999000.0   94640000.0   95421000.0
# 2024-05-23 09:00:00   95421000.0   96881000.0   93000000.0   94900000.0
# 2024-05-24 09:00:00   94897000.0   96160000.0   93300000.0   95214000.0
# ...                          ...          ...          ...          ...
# 2024-12-01 09:00:00  133722000.0  135199000.0  133297000.0  133802000.0
# 2024-12-02 09:00:00  133802000.0  135800000.0  132260000.0  133535000.0
# 2024-12-03 09:00:00  133523000.0  134680000.0   88266000.0  133700000.0
# 2024-12-04 09:00:00  133720000.0  139920000.0  133499000.0  138760000.0
# 2024-12-05 09:00:00  138765000.0  146100000.0  136980000.0  143729000.0
#
#                            volume         value
# 2024-05-20 09:00:00   4413.186165  4.168862e+11
# ...

# %%
print(pyupbit.get_ohlcv("KRW-BTC", to="20201010"))
# Out:
#                            open        high         low       close  \
# 2020-03-24 09:00:00   8047000.0   8412000.0   7892000.0   8367000.0
# 2020-03-25 09:00:00   8362000.0   8538000.0   8080000.0   8271000.0
# 2020-03-26 09:00:00   8276000.0   8344000.0   8091000.0   8272000.0
# 2020-03-27 09:00:00   8281000.0   8365000.0   7820000.0   7880000.0
# 2020-03-28 09:00:00   7883000.0   7885000.0   7403000.0   7656000.0
# ...                         ...         ...         ...         ...
# 2020-10-05 09:00:00  12446000.0  12545000.0  12385000.0  12536000.0
# 2020-10-06 09:00:00  12536000.0  12600000.0  12330000.0  12418000.0
# 2020-10-07 09:00:00  12408000.0  12435000.0  12337000.0  12423000.0
# 2020-10-08 09:00:00  12422000.0  12680000.0  12280000.0  12582000.0
# 2020-10-09 09:00:00  12582000.0  12750000.0  12503000.0  12638000.0
#
#                            volume         value
# 2020-03-24 09:00:00  15158.039589  1.244216e+11
# 2020-03-25 09:00:00  12629.118008  1.043876e+11
# ...

# %%
df = pyupbit.get_ohlcv("KRW-BTC",count = 1500, period=1,interval="minute1", to="20241204")

# %%
df_doge = pyupbit.get_ohlcv("KRW-DOGE",count = 1500, period=1,interval="minute1", to="20241204")

# %%
df.tail()
# Out:
#                             open         high          low        close  \
# 2024-12-04 08:55:00  133933000.0  133950000.0  133800000.0  133850000.0
# 2024-12-04 08:56:00  133850000.0  133884000.0  133770000.0  133770000.0
# 2024-12-04 08:57:00  133778000.0  133826000.0  133661000.0  133700000.0
# 2024-12-04 08:58:00  133700000.0  133764000.0  133663000.0  133703000.0
# 2024-12-04 08:59:00  133721000.0  133722000.0  133700000.0  133700000.0
#
#                         volume         value
# 2024-12-04 08:55:00   8.597533  1.150999e+09
# 2024-12-04 08:56:00   6.875574  9.199737e+08
# 2024-12-04 08:57:00  10.664385  1.426110e+09
# 2024-12-04 08:58:00   5.224663  6.986560e+08
# 2024-12-04 08:59:00   6.741782  9.014628e+08

# %%
df[750:].index
# Out:
# DatetimeIndex(['2024-12-03 20:30:00', '2024-12-03 20:31:00',
#                '2024-12-03 20:32:00', '2024-12-03 20:33:00',
#                '2024-12-03 20:34:00', '2024-12-03 20:35:00',
#                '2024-12-03 20:36:00', '2024-12-03 20:37:00',
#                '2024-12-03 20:38:00', '2024-12-03 20:39:00',
#                ...
#                '2024-12-04 08:50:00', '2024-12-04 08:51:00',
#                '2024-12-04 08:52:00', '2024-12-04 08:53:00',
#                '2024-12-04 08:54:00', '2024-12-04 08:55:00',
#                '2024-12-04 08:56:00', '2024-12-04 08:57:00',
#                '2024-12-04 08:58:00', '2024-12-04 08:59:00'],
#               dtype='datetime64[ns]', length=750, freq=None)

# %%
# df = df[750:]

# %%
len(df)
# Out:
# 1500

# %%
del df['value']

# %%
# pip install matplotlib

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
# plt.plot(df.index,df['open'],color = 'red')
plt.plot(df[:].index,df['high'],color = 'blue')
# plt.plot(df.index,df['low'],color = 'green')
# plt.plot(df.index,df['close'],color ='yellow')
# plt.plot(df.index,df['volume'],color = 'purple')
plt.xlabel('time')
plt.ylabel('High')
plt.grid()
plt.show()

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(6,6))
# plt.plot(df.index,df['open'],color = 'red')
# plt.plot(df[:].index,df['high'],color = 'blue')
# plt.plot(df.index,df['low'],color = 'green')
# plt.plot(df.index,df['close'],color ='yellow')
plt.plot(df.index,df['volume'],color = 'purple')
plt.xlabel('time')
plt.ylabel('High')
plt.show()

# %%
# pip install tensorflow

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
from tensorflow.keras import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense

# %%
def MinMaxScaler(data):
    k = data - np.min(data)
    j = np.max(data,0) - np.mine(data,0)
    return k / ( j + 1e-7)

# %%
df.head()
# Out:
#                             open         high          low        close  \
# 2024-12-03 08:00:00  133095000.0  133185000.0  133058000.0  133124000.0
# 2024-12-03 08:01:00  133124000.0  133124000.0  133050000.0  133050000.0
# 2024-12-03 08:02:00  133055000.0  133166000.0  133049000.0  133067000.0
# 2024-12-03 08:03:00  133067000.0  133186000.0  133056000.0  133155000.0
# 2024-12-03 08:04:00  133155000.0  133199000.0  133114000.0  133198000.0
#
#                        volume
# 2024-12-03 08:00:00  3.742963
# 2024-12-03 08:01:00  1.535930
# 2024-12-03 08:02:00  1.465094
# 2024-12-03 08:03:00  1.545046
# 2024-12-03 08:04:00  2.116402

# %%
df_doge.head()
# Out:
#                       open   high    low  close        volume         value
# 2024-12-03 08:00:00  589.1  589.4  588.7  588.7  8.532063e+05  5.025885e+08
# 2024-12-03 08:01:00  589.0  589.1  588.6  589.0  4.421351e+05  2.603395e+08
# 2024-12-03 08:02:00  589.0  589.9  588.9  589.8  5.341500e+05  3.148723e+08
# 2024-12-03 08:03:00  589.8  591.6  589.7  591.4  1.347336e+06  7.959611e+08
# 2024-12-03 08:04:00  591.4  592.8  591.3  591.7  1.878868e+06  1.112347e+09

# %%
bit_normal_df = ((df['high']-df['high'].min())/(df['high'].max() - df['high'].min()))

# %%
bit_normal_df.head()
# Out:
# 2024-12-03 08:00:00    0.962465
# 2024-12-03 08:01:00    0.960934
# 2024-12-03 08:02:00    0.961988
# 2024-12-03 08:03:00    0.962491
# 2024-12-03 08:04:00    0.962817
# Name: high, dtype: float64

# %%
doge_normal_df = ((df_doge['high']-df_doge['high'].min())/(df_doge['high'].max() - df_doge['high'].min()))

# %%
doge_normal_df.head()
# Out:
# 2024-12-03 08:00:00    0.931004
# 2024-12-03 08:01:00    0.929659
# 2024-12-03 08:02:00    0.933244
# 2024-12-03 08:03:00    0.940860
# 2024-12-03 08:04:00    0.946237
# Name: high, dtype: float64

# %%
bit_volume_normal_df = ((df['volume']-df['volume'].min())/(df['volume'].max() - df['volume'].min()))

# %%
Doge_volume_normal_df = ((df_doge['volume']-df_doge['volume'].min())/(df_doge['volume'].max() - df_doge['volume'].min()))

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index,bit_normal_df,color = 'red',label = 'Bit coin high')
plt.plot(df.index,doge_normal_df, color = 'blue', label = 'Doge coin high')

plt.legend()
plt.show()

# %%
plt.figure(figsize=(12,6))
plt.plot(df.index,bit_volume_normal_df,color = 'green',label = 'Bit coin volume')
plt.plot(df.index,Doge_volume_normal_df,color = 'purple',label = 'Doge coin volume')
plt.legend()
plt.show()

# %%
df_copy = df_doge

# %%
df_copy.head()
# Out:
#                       open   high    low  close        volume         value
# 2024-12-03 08:00:00  589.1  589.4  588.7  588.7  8.532063e+05  5.025885e+08
# 2024-12-03 08:01:00  589.0  589.1  588.6  589.0  4.421351e+05  2.603395e+08
# 2024-12-03 08:02:00  589.0  589.9  588.9  589.8  5.341500e+05  3.148723e+08
# 2024-12-03 08:03:00  589.8  591.6  589.7  591.4  1.347336e+06  7.959611e+08
# 2024-12-03 08:04:00  591.4  592.8  591.3  591.7  1.878868e+06  1.112347e+09

# %%
df_reset = df_copy.reset_index()

# %%
df_reset.head()
# Out:
#                 index   open   high    low  close        volume         value
# 0 2024-12-03 08:00:00  589.1  589.4  588.7  588.7  8.532063e+05  5.025885e+08
# 1 2024-12-03 08:01:00  589.0  589.1  588.6  589.0  4.421351e+05  2.603395e+08
# 2 2024-12-03 08:02:00  589.0  589.9  588.9  589.8  5.341500e+05  3.148723e+08
# 3 2024-12-03 08:03:00  589.8  591.6  589.7  591.4  1.347336e+06  7.959611e+08
# 4 2024-12-03 08:04:00  591.4  592.8  591.3  591.7  1.878868e+06  1.112347e+09

# %%
# pip install seaborn

# %%
import seaborn as sns

# %%
# bit_normal_df
# bit_volume_normal_df
# doge_normal_df
# Doge_volume_normal_df

# pd.concat
# Out:
# <function pandas.core.reshape.concat.concat(objs: 'Iterable[Series | DataFrame] | Mapping[HashableT, Series | DataFrame]', *, axis: 'Axis' = 0, join: 'str' = 'outer', ignore_index: 'bool' = False, keys: 'Iterable[Hashable] | None' = None, levels=None, names: 'list[HashableT] | None' = None, verify_integrity: 'bool' = False, sort: 'bool' = False, copy: 'bool | None' = None) -> 'DataFrame | Series'>

# %%
# plt.figure(figsize=(6,6))
# sns.heatmap()

# %%
print(pyupbit.get_tickers(fiat="KRW-S"))
# Out:
# ['KRW-SNT', 'KRW-STEEM', 'KRW-STORJ', 'KRW-SBD', 'KRW-SC', 'KRW-STPT', 'KRW-STMX', 'KRW-SXP', 'KRW-STRAX', 'KRW-SAND', 'KRW-STRIKE', 'KRW-STX', 'KRW-SOL', 'KRW-SHIB', 'KRW-SUI', 'KRW-SEI', 'KRW-STG', 'KRW-SAFE']

# %%
corr_Bit_df = pyupbit.get_ohlcv("KRW-BTC",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_Ether_df = pyupbit.get_ohlcv("KRW-ETH",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_tether_df = pyupbit.get_ohlcv("KRW-USDT",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_Doge_df = pyupbit.get_ohlcv("KRW-DOGE",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_Sand_df = pyupbit.get_ohlcv("KRW-SAND",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_XRP_df = pyupbit.get_ohlcv("KRW-XRP",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_Solana_df = pyupbit.get_ohlcv("KRW-SOL",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_pepe_df = pyupbit.get_ohlcv("KRW-PEPE",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_pepe_df
# Out:
#                         open     high      low    close        volume  \
# 2024-11-14 09:00:00  0.02624  0.06199  0.02624  0.03388  1.510894e+13
# 2024-11-14 13:00:00  0.03388  0.03517  0.03165  0.03249  6.132243e+12
# 2024-11-14 17:00:00  0.03248  0.03326  0.02915  0.03027  5.466957e+12
# 2024-11-14 21:00:00  0.03023  0.03197  0.02875  0.02965  5.392016e+12
# 2024-11-15 01:00:00  0.02967  0.03321  0.02927  0.03193  3.129940e+12
# ...                      ...      ...      ...      ...           ...
# 2024-12-03 13:00:00  0.02842  0.02931  0.02826  0.02878  8.271724e+11
# 2024-12-03 17:00:00  0.02878  0.02904  0.02812  0.02828  5.666668e+11
# 2024-12-03 21:00:00  0.02833  0.02848  0.01634  0.02717  2.240095e+12
# 2024-12-04 01:00:00  0.02717  0.02788  0.02691  0.02760  4.609614e+11
# 2024-12-04 05:00:00  0.02760  0.02895  0.02758  0.02830  5.529708e+11
#
#                             value
# 2024-11-14 09:00:00  5.787941e+11
# 2024-11-14 13:00:00  2.038226e+11
# ...

# %%
corr_Shib_df = pyupbit.get_ohlcv("KRW-SHIB",count = 2200, period=1,interval= "minute240", to="20241204")

# %%
corr_Shib_df
# Out:
#                         open     high      low    close        volume  \
# 2023-12-03 13:00:00  0.01140  0.01150  0.01130  0.01140  3.098170e+10
# 2023-12-03 17:00:00  0.01140  0.01140  0.01120  0.01120  7.345054e+10
# 2023-12-03 21:00:00  0.01130  0.01140  0.01120  0.01120  8.943876e+10
# 2023-12-04 05:00:00  0.01130  0.01240  0.01130  0.01210  5.133492e+11
# 2023-12-04 09:00:00  0.01220  0.01220  0.01190  0.01200  1.705868e+11
# ...                      ...      ...      ...      ...           ...
# 2024-12-03 13:00:00  0.04070  0.04316  0.04044  0.04128  2.784355e+12
# 2024-12-03 17:00:00  0.04130  0.04168  0.04035  0.04055  1.206327e+12
# 2024-12-03 21:00:00  0.04054  0.04105  0.02100  0.03891  8.515542e+12
# 2024-12-04 01:00:00  0.03891  0.04001  0.03835  0.03946  2.207581e+12
# 2024-12-04 05:00:00  0.03946  0.04042  0.03942  0.03994  1.287477e+12
#
#                             value
# 2023-12-03 13:00:00  3.529554e+08
# 2023-12-03 17:00:00  8.328210e+08
# ...

# %%
# Bit_high = corr_Bit_df['high']
# Ether_high = corr_Ether_df['high']
# tether_high = corr_tether_df['high']
# Doge_high = corr_Doge_df['high']
# Sand_high = corr_Sand_df['high']
# XRP_high = corr_XRP_df['high']
# Solana_high = corr_Solana_df['high']
# pepe_high = corr_pepe_df['high']
# Shib_high = corr_Shib_df['high']

# %%
bit_high = corr_Bit_df['high']
dog_high = corr_Doge_df['high']
eth_high = corr_Ether_df['high']
sol_high = corr_Solana_df['high']
sand_high = corr_Sand_df ['high']
shib_high = corr_Shib_df['high']
XRP_high = corr_XRP_df['high']
pepe_high = corr_pepe_df['high']
tether_high = corr_tether_df['high']

import pandas as pd
data = {
    "Bitcoin_High": bit_high,
    "Dogecoin_High": dog_high,
    "Ethereum_High": eth_high,
    "Solana_High": sol_high,
    "Sandbox_High": sand_high,
    "Shiba_High": shib_high,
    "XRP_High": XRP_high,
    "Tether_High": tether_high,
}
crypto_highs_df = pd.DataFrame(data)
correlation_matrix = crypto_highs_df.corr()
correlation_matrix

import seaborn as sns
plt.figure (figsize= (10,10))
sns.heatmap(correlation_matrix, cmap = 'coolwarm', annot =True, square = True, fmt = '.2f')
plt.title ('Major Coin vs Minor Coin')
plt.show()

# %%
bit_normal_df = ((corr_Bit_df['high']-corr_Bit_df['high'].min())/(corr_Bit_df['high'].max() - corr_Bit_df['high'].min()))
dog_normal_df = ((corr_Doge_df['high'] -corr_Doge_df['high'] .min())/(corr_Doge_df['high'] .max() - corr_Doge_df['high'] .min()))
sol_normal_df = ((corr_Solana_df['high']-corr_Solana_df['high'].min())/(corr_Solana_df['high'].max() - corr_Solana_df['high'].min()))

# %%
plt.figure(figsize=(12, 6))
plt.plot(bit_normal_df, label='Bitcoin', color='blue', linewidth=2)
plt.plot(dog_normal_df, label='Dogecoin', color='orange', alpha=0.2)
plt.plot(sol_normal_df, label='Solana', color='green', alpha=0.2)
plt.title('Normalized High Prices of Cryptocurrencies', fontsize=16)
plt.xlabel('Index', fontsize=12)
plt.ylabel('Normalized High Price', fontsize=12)
plt.legend()
plt.grid(alpha=0.3)
plt.tight_layout()
plt.show()

# %%
# pip install dtw-python

# %%
# pip install dtaidistance

# %%
import numpy as np
from dtw import dtw
# Out:
# Importing the dtw module. When using in academic works please cite:
#   T. Giorgino. Computing and Visualizing Dynamic Time Warping Alignments in R: The dtw Package.
#   J. Stat. Soft., doi:10.18637/jss.v031.i07.

# %%
from dtaidistance import dtw

# %%
x = (bit_normal_df.to_list())
y = (dog_normal_df.to_list())
distance, paths = dtw.warping_paths(x, y)
print(distance)
# Out:
# 3.781757882895056

# %%
# 필요한 라이브러리 설치 (터미널에서 설치)
# pip install dtaidistance matplotlib

from dtaidistance import dtw
from dtaidistance import dtw_visualisation as dtwvis
import matplotlib.pyplot as plt

# 두 시계열 데이터 정의
series1 = x
series2 = y

# DTW 거리 계산
distance = dtw.distance(series1, series2)
print(f"DTW 거리: {distance}")

# DTW 경로 계산
alignment = dtw.warping_path(series1, series2)

# 시각화: 두 시계열의 DTW 정렬 경로
dtwvis.plot_warping(series1, series2, alignment)
plt.title("DTW")
plt.show()
# Out:
# DTW 거리: 3.781757882895056

# %%
xrp_normal_df = ((corr_XRP_df['high']-corr_XRP_df['high'].min())/(corr_XRP_df['high'].max() - corr_XRP_df['high'].min()))

# %%
x = (bit_normal_df.to_list())
y = (xrp_normal_df.to_list())
distance, paths = dtw.warping_paths(x, y)
print(distance)
# Out:
# 1.8945731503387604

# %%
# 필요한 라이브러리 설치 (터미널에서 설치)
# pip install dtaidistance matplotlib

# from dtaidistance import dtw
# from dtaidistance import dtw_visualisation as dtwvis
# import matplotlib.pyplot as plt

# 두 시계열 데이터 정의
series1 = x
series2 = y

# DTW 거리 계산
distance = dtw.distance(series1, series2)
print(f"DTW 거리: {distance}")

# DTW 경로 계산
alignment = dtw.warping_path(series1, series2)

# 시각화: 두 시계열의 DTW 정렬 경로
dtwvis.plot_warping(series1, series2, alignment)
plt.title("DTW")
plt.show()
# Out:
# DTW 거리: 1.8945731503387604
